# %%
import pandas as pd

# %%
pd.DataFrame({'Yes':[50, 21], 'No':[131, 2]})
# Out:
#    Yes   No
# 0   50  131
# 1   21    2

# %%
pd.DataFrame({'Bob':['I liked it.', 'It was awful.'], 'Sue':['Pretty good.', 'Bland.']},
             index=['Product A', 'Product B'])
# Out:
#                      Bob           Sue
# Product A    I liked it.  Pretty good.
# Product B  It was awful.        Bland.

# %%
pd.Series([1,2,3,4,5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
pd.Series([30, 35, 40], index=['2015 Sales', '2016 Sales', '2017 Sales'], name='Product A')
# Out:
# 2015 Sales    30
# 2016 Sales    35
# 2017 Sales    40
# Name: Product A, dtype: int64

# %%
house_price = pd.read_csv("D:\Programming\machine learning\Intro to Machine Learning\input\melb_data.csv")
house_price.shape
# Out:
# (13580, 21)

# %%
house_price.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
house_price.Suburb
# Out:
# 0           Abbotsford
# 1           Abbotsford
# 2           Abbotsford
# 3           Abbotsford
# 4           Abbotsford
#              ...
# 13575    Wheelers Hill
# 13576     Williamstown
# 13577     Williamstown
# 13578     Williamstown
# 13579       Yarraville
# Name: Suburb, Length: 13580, dtype: object

# %%
house_price['Suburb']
# Out:
# 0           Abbotsford
# 1           Abbotsford
# 2           Abbotsford
# 3           Abbotsford
# 4           Abbotsford
#              ...
# 13575    Wheelers Hill
# 13576     Williamstown
# 13577     Williamstown
# 13578     Williamstown
# 13579       Yarraville
# Name: Suburb, Length: 13580, dtype: object

# %%
house_price['Suburb'][0]
# Out:
# 'Abbotsford'

# %%
house_price.loc[0,'Rooms']
# Out:
# 2

# %%
house_price.iloc[:5,2]
# Out:
# 0    2
# 1    2
# 2    3
# 3    3
# 4    4
# Name: Rooms, dtype: int64

# %%
house_price.set_index('Price')
# Out:
#                   Suburb           Address  Rooms Type Method   SellerG  \
# Price
# 1480000.0     Abbotsford      85 Turner St      2    h      S    Biggin
# 1035000.0     Abbotsford   25 Bloomburg St      2    h      S    Biggin
# 1465000.0     Abbotsford      5 Charles St      3    h     SP    Biggin
# 850000.0      Abbotsford  40 Federation La      3    h     PI    Biggin
# 1600000.0     Abbotsford       55a Park St      4    h     VB    Nelson
# ...                  ...               ...    ...  ...    ...       ...
# 1245000.0  Wheelers Hill      12 Strada Cr      4    h      S     Barry
# 1031000.0   Williamstown     77 Merrett Dr      3    h     SP  Williams
# 1170000.0   Williamstown       83 Power St      3    h      S     Raine
# 2500000.0   Williamstown      96 Verdon St      4    h     PI   Sweeney
# 1285000.0     Yarraville        6 Agnes St      4    h     SP   Village
#
#                  Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# Price
# ...

# %%
house_price.loc[(house_price.Rooms == 2) & (house_price.Distance>10)]
# Out:
#                Suburb             Address  Rooms Type     Price Method  \
# 41       Airport West          23 Hart St      2    h  603000.0      S
# 44       Airport West    2/49 McIntosh St      2    u  500000.0     VB
# 48       Airport West      2/252 Parer Rd      2    t  450000.0      S
# 49       Airport West        3/19 Hart St      2    u  515000.0      S
# 50       Airport West  2/62 Clydesdale Rd      2    u  530000.0      S
# ...               ...                 ...    ...  ...       ...    ...
# 13512        Oakleigh          3 Grant St      2    h  875000.0     PI
# 13513  Oakleigh South         33 Guest Rd      2    h  985000.0     PI
# 13530       Reservoir          92 Pine St      2    u  625500.0      S
# 13533   Ringwood East       14 Everard Rd      2    h  937000.0      S
# 13572        Watsonia       76 Kenmare St      2    h  650000.0     PI
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %%
house_price.loc[house_price.Suburb.isin(['Airport West'])]
# Out:
#              Suburb          Address  Rooms Type      Price Method    SellerG  \
# 38     Airport West    154 Halsey Rd      3    t   840000.0     PI     Nelson
# 39     Airport West    50 Bedford St      3    h   730000.0     VB     Nelson
# 40     Airport West    50 Bedford St      3    h   770000.0     SP     Nelson
# 41     Airport West       23 Hart St      2    h   603000.0      S     Nelson
# 42     Airport West   1/80 Hawker St      3    t   700000.0      S       Brad
# ...             ...              ...    ...  ...        ...    ...        ...
# 12429  Airport West     78 Hawker St      3    h  1064000.0      S      Barry
# 13088  Airport West    33 Bedford St      3    h   860000.0      S  Harcourts
# 13089  Airport West  16 Highridge Cr      3    h   850000.0      S       Brad
# 13334  Airport West     11 Grange Rd      3    h   975500.0      S      Barry
# 13335  Airport West     125 Parer Rd      3    h   880000.0      S     Jellis
#
# ...

# %%
house_price.loc[house_price.Price.isnull()]
# Out:
# Empty DataFrame
# Columns: [Suburb, Address, Rooms, Type, Price, Method, SellerG, Date, Distance, Postcode, Bedroom2, Bathroom, Car, Landsize, BuildingArea, YearBuilt, CouncilArea, Lattitude, Longtitude, Regionname, Propertycount]
# Index: []
#
# [0 rows x 21 columns]

# %%
house_price['Suburb'] = 'A'
house_price['Suburb']
# Out:
# 0        A
# 1        A
# 2        A
# 3        A
# 4        A
#         ..
# 13575    A
# 13576    A
# 13577    A
# 13578    A
# 13579    A
# Name: Suburb, Length: 13580, dtype: object

# %%
house_price['Price'] = range(len(house_price), 0, -1)
house_price['Price']
# Out:
# 0        13580
# 1        13579
# 2        13578
# 3        13577
# 4        13576
#          ...
# 13575        5
# 13576        4
# 13577        3
# 13578        2
# 13579        1
# Name: Price, Length: 13580, dtype: int32

# %%
house = pd.read_csv("D:\Programming\machine learning\Intro to Machine Learning\input\melb_data.csv")
house.BuildingArea
# Out:
# 0          NaN
# 1         79.0
# 2        150.0
# 3          NaN
# 4        142.0
#          ...
# 13575      NaN
# 13576    133.0
# 13577      NaN
# 13578    157.0
# 13579    112.0
# Name: BuildingArea, Length: 13580, dtype: float64

# %%
house.Rooms.describe()
# Out:
# count    13580.000000
# mean         2.937997
# std          0.955748
# min          1.000000
# 25%          2.000000
# 50%          3.000000
# 75%          3.000000
# max         10.000000
# Name: Rooms, dtype: float64

# %%
house_rooms_mean = house.Rooms.mean()
house_rooms_mean
# Out:
# 2.9379970544919

# %%
house.Method.unique()
# Out:
# array(['S', 'SP', 'PI', 'VB', 'SA'], dtype=object)

# %%
house.Method.value_counts()
# Out:
# S     9022
# SP    1703
# PI    1564
# VB    1199
# SA      92
# Name: Method, dtype: int64

# %%
house.Rooms.map(lambda p: p - house_rooms_mean)
# Out:
# 0       -0.937997
# 1       -0.937997
# 2        0.062003
# 3        0.062003
# 4        1.062003
#            ...
# 13575    1.062003
# 13576    0.062003
# 13577    0.062003
# 13578    1.062003
# 13579    1.062003
# Name: Rooms, Length: 13580, dtype: float64

# %%
house.groupby('Rooms').Rooms.count()
# Out:
# Rooms
# 1      681
# 2     3648
# 3     5881
# 4     2688
# 5      596
# 6       67
# 7       10
# 8        8
# 10       1
# Name: Rooms, dtype: int64

# %%
house.groupby('Rooms').Price.min()
# Out:
# Rooms
# 1       85000.0
# 2      190000.0
# 3      283000.0
# 4      131000.0
# 5      355000.0
# 6      506000.0
# 7     1005000.0
# 8      741000.0
# 10     900000.0
# Name: Price, dtype: float64

# %%
house.groupby('Rooms').Price.agg([len, min, max])
# Out:
#           len        min        max
# Rooms
# 1       681.0    85000.0  2450000.0
# 2      3648.0   190000.0  4800000.0
# 3      5881.0   283000.0  9000000.0
# 4      2688.0   131000.0  7650000.0
# 5       596.0   355000.0  8000000.0
# 6        67.0   506000.0  6500000.0
# 7        10.0  1005000.0  4050000.0
# 8         8.0   741000.0  2950000.0
# 10        1.0   900000.0   900000.0

# %%
house_re = house.groupby(['Suburb','Rooms']).Price.agg([len])
house_re
# Out:
#                    len
# Suburb     Rooms
# Abbotsford 1       5.0
#            2      27.0
#            3      20.0
#            4       4.0
# Aberfeldie 1       4.0
# ...                ...
# Yarraville 2      44.0
#            3      84.0
#            4      27.0
#            5       3.0
#            6       1.0
#
# [1117 rows x 1 columns]

# %%
mi = house_re.index
type(mi)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
house_re = house_re.reset_index()
house_re
# Out:
#           Suburb  Rooms   len
# 0     Abbotsford      1   5.0
# 1     Abbotsford      2  27.0
# 2     Abbotsford      3  20.0
# 3     Abbotsford      4   4.0
# 4     Aberfeldie      1   4.0
# ...          ...    ...   ...
# 1112  Yarraville      2  44.0
# 1113  Yarraville      3  84.0
# 1114  Yarraville      4  27.0
# 1115  Yarraville      5   3.0
# 1116  Yarraville      6   1.0
#
# [1117 rows x 3 columns]

# %%
house_re.sort_values(by='len',ascending=False)
# Out:
#               Suburb  Rooms    len
# 863        Reservoir      3  171.0
# 115   Bentleigh East      3  139.0
# 854          Preston      3  136.0
# 862        Reservoir      2  117.0
# 867         Richmond      2  113.0
# ...              ...    ...    ...
# 435    Essendon West      7    1.0
# 436        Fairfield      1    1.0
# 448   Ferntree Gully      5    1.0
# 896        Sandhurst      4    1.0
# 1116      Yarraville      6    1.0
#
# [1117 rows x 3 columns]

# %%
house_re.sort_index()
# Out:
#           Suburb  Rooms   len
# 0     Abbotsford      1   5.0
# 1     Abbotsford      2  27.0
# 2     Abbotsford      3  20.0
# 3     Abbotsford      4   4.0
# 4     Aberfeldie      1   4.0
# ...          ...    ...   ...
# 1112  Yarraville      2  44.0
# 1113  Yarraville      3  84.0
# 1114  Yarraville      4  27.0
# 1115  Yarraville      5   3.0
# 1116  Yarraville      6   1.0
#
# [1117 rows x 3 columns]

# %%
house_re.sort_values(by=['Rooms', 'len'])
# Out:
#                   Suburb  Rooms  len
# 49            Ascot Vale      1  1.0
# 166         Broadmeadows      1  1.0
# 188              Bulleen      1  1.0
# 250            Caulfield      1  1.0
# 304         Coburg North      1  1.0
# ...                  ...    ...  ...
# 559   Heidelberg Heights      8  1.0
# 690       Meadow Heights      8  1.0
# 772              Newport      8  1.0
# 1010   Templestowe Lower      8  1.0
# 198             Bundoora     10  1.0
#
# [1117 rows x 3 columns]

# %%
house.dtypes
# Out:
# Suburb            object
# Address           object
# Rooms              int64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# dtype: object

# %%
house.Rooms.astype('float64')
# Out:
# 0        2.0
# 1        2.0
# 2        3.0
# 3        3.0
# 4        4.0
#         ...
# 13575    4.0
# 13576    3.0
# 13577    3.0
# 13578    4.0
# 13579    4.0
# Name: Rooms, Length: 13580, dtype: float64

# %%
house[pd.isnull(house.BuildingArea)]
# Out:
#                Suburb             Address  Rooms Type      Price Method  \
# 0          Abbotsford        85 Turner St      2    h  1480000.0      S
# 3          Abbotsford    40 Federation La      3    h   850000.0     PI
# 5          Abbotsford      129 Charles St      2    h   941000.0      S
# 8          Abbotsford  6/241 Nicholson St      1    u   300000.0      S
# 10         Abbotsford  411/8 Grosvenor St      2    u   700000.0     VB
# ...               ...                 ...    ...  ...        ...    ...
# 13569  Wantirna South        12 Armagh Cr      4    h  1323000.0      S
# 13570  Wantirna South       34 Fewster Dr      3    h   970000.0      S
# 13574     Westmeadows          9 Black St      3    h   582000.0      S
# 13575   Wheelers Hill        12 Strada Cr      4    h  1245000.0      S
# 13577    Williamstown         83 Power St      3    h  1170000.0      S
#
#       SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %%
house.BuildingArea.fillna("Unknowen")
# Out:
# 0        Unknowen
# 1              79
# 2             150
# 3        Unknowen
# 4             142
#            ...
# 13575    Unknowen
# 13576         133
# 13577    Unknowen
# 13578         157
# 13579         112
# Name: BuildingArea, Length: 13580, dtype: object

# %%
house.BuildingArea.replace(79, 80)
# Out:
# 0          NaN
# 1         80.0
# 2        150.0
# 3          NaN
# 4        142.0
#          ...
# 13575      NaN
# 13576    133.0
# 13577      NaN
# 13578    157.0
# 13579    112.0
# Name: BuildingArea, Length: 13580, dtype: float64

# %%
house.rename(columns={'BuildingArea':'Area'})
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...
